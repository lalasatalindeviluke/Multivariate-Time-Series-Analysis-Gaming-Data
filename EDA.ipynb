# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
horizon = pd.read_csv(".\\data\\horizon2_stationaryFPS.csv", encoding="utf-8", index_col=0)
horizon.head()
# Out:
#        已提交的虛擬內存 [兆字節]  可用虛擬內存 [兆字節]  虛擬內存負載 [%]  使用的物理內存 [兆字節]  可用物理內存 [兆字節]  \
# index
# 0               21998         15531        58.6          11193         21471
# 1               21989         15539        58.5          11191         21474
# 2               21905         15624        58.3          11191         21473
# 3               21847         15682        58.2          11154         21510
# 4               21841         15688        58.1          11172         21493
#
#        物理內存負載 [%]  Core VIDs (avg) [V]  Core 0 VID [V]  Core 1 VID [V]  \
# index
# 0            34.2                1.251           1.262           1.253
# 1            34.2                1.252           1.238           1.245
# 2            34.2                1.252           1.232           1.235
# 3            34.1                1.240           1.250           1.242
# 4            34.2                1.245           1.250           1.243
#
#        Core 2 VID [V]  ...  GPU D3D 內存專用 [兆字節]  GPU D3D 內存動態 [兆字節]  \
# index                  ...
# 0               1.253  ...                8876                 653
# 1               1.245  ...                8876                 653
# 2               1.254  ...                8877                 653
# 3               1.242  ...                8877                 653
# 4               1.243  ...                8877                 653
#
#        PCIe 鏈接速度 [GT/s]  總下載量 [兆字節]  總上傳 [兆字節]  當前下載速度 [KB/s]  當前上傳速率 [KB/s]  \
# index
# 0                    16          11          2          1.218          0.030
# 1                    16          11          2          1.095          0.581
# 2                    16          11          2          0.491          1.378
# 3                    16          11          2          0.325          0.052
# 4                    16          11          2          0.330          0.030
#
#        幀率 [FPS]  幀時間 [ms]  Column1
# index
# 0           113       6.6      NaN
# 1           146       9.7      NaN
# 2           147       4.5      NaN
# 3           150       6.3      NaN
# 4           152       5.4      NaN
#
# [5 rows x 166 columns]

# %%
horizon.shape
# Out:
# (3193, 166)

# %%
plt.figure(figsize=(21, 9))
plt.plot(horizon["幀率 [FPS]"].to_numpy())
plt.title("FPS")
plt.ylabel("Frame per Second")
plt.grid()
plt.show()

# %%
horizon["幀率 [FPS]"].describe()
# Out:
# count    3193.000000
# mean      137.177889
# std        15.997444
# min        91.000000
# 25%       126.000000
# 50%       136.000000
# 75%       148.000000
# max       190.000000
# Name: 幀率 [FPS], dtype: float64
