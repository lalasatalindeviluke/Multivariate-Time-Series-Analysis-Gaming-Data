# %%
import pandas as pd

# %%
var_list = [
    "使用的物理內存 [兆字節]",
    "平均有效時脈 [兆赫]",
    "CPU整體功耗 [W]",
    # "系統 Agent 能量消耗 [W]",
    "CPU [℃]",
    "CPU [RPM]",
    "讀取率 [MB/s]_21",
    # "讀取總數 [兆字節]_23",
    "GPU 溫度 [℃]",
    "GPU 內存結溫 [℃]",
    "GPU核心電壓 [V]",
    "GPU 能量消耗 [W]",
    "GPU 有效時脈 [兆赫]",
    "分配的 GPU 內存 [兆字節]",
    "幀率 [FPS]",
    "幀時間 [ms]"
]

# %%
horizon = pd.read_csv("..\\data\\horizon2_stationaryFPS.csv", encoding="utf-8", index_col=0,
                      usecols=var_list)
horizon.rename(
    columns={
    "使用的物理內存 [兆字節]": "使用的物理記憶體 [兆字節]",
    "讀取率 [MB/s]_21": "SSD讀取率 [MB/s]",
    "讀取總數 [兆字節]_23": "SSD讀取總數 [兆字節]",
    "GPU 內存結溫 [℃]": "GPU 記憶體溫度 [℃]",
    "分配的 GPU 內存 [兆字節]": "分配的 GPU 記憶體 [兆字節]"
    },
    inplace=True
)
horizon.head()
# Out:
#                平均有效時脈 [兆赫]  CPU整體功耗 [W]  CPU [℃]  CPU [RPM]  SSD讀取率 [MB/s]  \
# 使用的物理內存 [兆字節]
# 11193               2295.4       99.895     54.0       1494          0.000
# 11191               2598.2      104.135     55.5       1481          0.947
# 11191               2741.5      107.012     56.0       1538          0.400
# 11154               2660.6      105.918     56.0       1530          0.349
# 11172               2598.3      103.853     55.5       1517          0.756
#
#                GPU 溫度 [℃]  GPU 記憶體溫度 [℃]  GPU核心電壓 [V]  GPU 能量消耗 [W]  \
# 使用的物理內存 [兆字節]
# 11193                76.5             80        1.056       305.353
# 11191                76.9             80        1.056       341.418
# 11191                77.1             82        1.056       345.209
# 11154                76.9             82        1.031       342.610
# 11172                76.7             82        1.031       345.456
#
#                GPU 有效時脈 [兆赫]  分配的 GPU 記憶體 [兆字節]  幀率 [FPS]  幀時間 [ms]
# ...

# %%
# horizon.to_csv("..\\data\\horizon_final.csv", index=False)

# %%
# horizon.to_csv("..\\data\\horizon_final_big5.csv", index=False, encoding="big5")
